# %%
# !pip install sdv
# Out:
# Requirement already satisfied: sdv in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (0.17.2)
# Requirement already satisfied: rdt<1.3.0,>=1.2.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (1.2.1)
# Requirement already satisfied: pandas<2,>=1.1.3 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (1.4.2)
# Requirement already satisfied: deepecho<0.4,>=0.3.0.post1 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (0.3.0.post1)
# Requirement already satisfied: sdmetrics<0.9,>=0.8.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (0.8.1)
# Requirement already satisfied: Faker<15,>=10 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (14.2.1)
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (2.2.0)
# Requirement already satisfied: copulas<0.8,>=0.7.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (0.7.0)
# Requirement already satisfied: ctgan<0.6,>=0.5.2 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (0.5.2)
# Requirement already satisfied: tqdm<5,>=4.15 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (4.64.0)
# Requirement already satisfied: numpy<2,>=1.20.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (1.21.5)
# Requirement already satisfied: graphviz<1,>=0.13.2 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdv) (0.20.1)
# Requirement already satisfied: scipy<2,>=1.5.4 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from copulas<0.8,>=0.7.0->sdv) (1.7.3)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from copulas<0.8,>=0.7.0->sdv) (3.5.1)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from ctgan<0.6,>=0.5.2->sdv) (1.0.2)
# Requirement already satisfied: torch<2,>=1.8.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from ctgan<0.6,>=0.5.2->sdv) (1.13.1)
# Requirement already satisfied: torchvision<1,>=0.9.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from ctgan<0.6,>=0.5.2->sdv) (0.14.1)
# Requirement already satisfied: packaging<22,>=20 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from ctgan<0.6,>=0.5.2->sdv) (21.3)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from Faker<15,>=10->sdv) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from pandas<2,>=1.1.3->sdv) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.4->Faker<15,>=10->sdv) (1.16.0)
# Requirement already satisfied: psutil<6,>=5.7 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from rdt<1.3.0,>=1.2.0->sdv) (5.8.0)
# Requirement already satisfied: pyyaml<6,>=5.4.1 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from rdt<1.3.0,>=1.2.0->sdv) (5.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<2,>=0.24->ctgan<0.6,>=0.5.2->sdv) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<2,>=0.24->ctgan<0.6,>=0.5.2->sdv) (1.1.0)
# Requirement already satisfied: plotly<6,>=5.10.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from sdmetrics<0.9,>=0.8.0->sdv) (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from plotly<6,>=5.10.0->sdmetrics<0.9,>=0.8.0->sdv) (8.0.1)
# Requirement already satisfied: typing-extensions in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from torch<2,>=1.8.0->ctgan<0.6,>=0.5.2->sdv) (4.1.1)
# Requirement already satisfied: requests in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.2->sdv) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.2->sdv) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.2->sdv) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.2->sdv) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/anthony/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.2->sdv) (1.26.9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('/Users/anthony/Downloads/keys.csv')
data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/anthony/Desktop/INTONE/sensitive/gen_data.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/anthony/Desktop/INTONE/sensitive/gen_data.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_csv('/Users/anthony/Downloads/keys.csv')
#       <a href='vscode-notebook-cell:/Users/anthony/Desktop/INTONE/sensitive/gen_data.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xaf in position 10: invalid start byte

# %%
data = data.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/anthony/Desktop/INTONE/sensitive/gen_data.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/anthony/Desktop/INTONE/sensitive/gen_data.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> data = data.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], axis=1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Unnamed: 1', 'Unnamed: 2'] not found in axis"

# %%
from sdv import load_demo
from sdv.tabular import GaussianCopula
model = GaussianCopula()
model.fit(data)

# %%
sample = model.sample(200000)
sample.head(10)
# Out:
#            SSN  bank account Passport no.                 card transaction_ID  \
# 0  099-52-2802  5.444452e+12    49SN87292  4314-6417-5269-5130   CTID89983002
# 1  925-64-0363  4.637668e+12    84DL48635  8066-8437-2479-2481   CTID19451148
# 2  357-10-7658  6.528341e+12    30EZ99677  7615-9021-6282-1834   CTID38846768
# 3  379 04 5699  5.267132e+12    53NT46760  1865 7979 5235 6125   CTID61506049
# 4     25151222  6.714649e+12    48QM30162  0613 7829 6768 6240   CTID99691250
# 5  663-30-8781  7.681526e+12    17ZJ09553  5378 8410 7008 9983   CTID86231606
# 6  256-17-1089  5.267982e+12    18JC44448  2776 8126 6754 9002   CTID15466546
# 7          NaN  5.595447e+12          NaN                  NaN   CTID91326074
# 8  923-49-9374  7.871737e+12    01AX98490                  NaN   CTID12335129
# 9  615-44-2702  6.435940e+12    49MD14143  1527 0934 6139 2731   CTID16027734
#
#         DL_EU         A_no   routing_no insurance_no         ITIN
# 0  26047822.0  521-388-277  0226-2949-9    FF256881D  923 86-5944
# 1  10194874.0  325-523-274  1220-9406-8    SB219645C  941 70-1643
# 2  52601167.0  466-454-528  1262-5881-7    AU694891A  952 76 6215
# 3  59963285.0  693-526-647  0380-7382-5    LQ884444A  910 71-7090
# 4  63133530.0  521-396-239  7307-5857-6    QW750070B  966 73 5181
# 5  30873957.0  116-199-034  2787-7304-9    EB025712D  993 80 7653
# 6  47936047.0  401-104-511  3836-2618-0    II952156B  903-89 5721
# 7  59778927.0  219-450-672          NaN    ZO391825B  931 78-6259
# 8  48312250.0  515-882-214  2076-1324-3    ZH343156B  931 81 5612
# 9  41718443.0  552-234-972  6601-3963-9    KT192659C  926 84-3649

# %%
sample.to_csv('big_data.csv')
